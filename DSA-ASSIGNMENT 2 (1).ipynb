# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\arund\Downloads\iris.xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (150, 5)

# %%
data.size
# Out:
# 750

# %%
# To display columns

data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
# To display basic info 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# To describe statistics about data

data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# Checking null values

data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
data.nunique()
# Out:
# SL                35
# SW                23
# PL                43
# PW                22
# Classification     3
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
plt.bar(data['Classification'],data['SL'],width=0.5)
plt.ylabel('Sepal Length')
plt.xlabel('Classification')
plt.title('SEPAL LENGTH OF DIFFERENT CLASSES')
plt.show()

# %%
fig,axs = plt.subplots(2,2,figsize=(8,8))

axs[0,0].bar(data['Classification'],data['SL'],width = 0.5,color='orange')
axs[0,0].set_title('Sepal length of different Species')


axs[0,1].bar(data['Classification'],data['SW'],width=0.5)
axs[0,1].set_title('Sepal width of different Species')


axs[1,0].bar(data['Classification'],data['PL'],width=0.5,color='green')
axs[1,0].set_title('Petal length of different Species')


axs[1,1].bar(data['Classification'],data['PW'],width=0.5,color='red')
axs[1,1].set_title('Petal width of different Species')


plt.tight_layout()

plt.show()

# %% [markdown]
# From the above plots we can see that
#
# 1) Iris-virginica has largest sepal length among the three species and Iris-setosa has the smallest.
# 2) Iris-setosa has the largest sepal width and Iris-versicolor has the smallest.
# 3) Iris-Virginica has the largest Petal Length and Iris-setosa has the smallest Petal Length.
# 4) In case of Petal Width Iris-Virginica has the largest value and Iris-Setosa has the smallest value.

# %%
fig,axs = plt.subplots(2,2,figsize=(8,8))


axs[0,0].hist(data['SL'],color='orange',bins=5)
axs[0,0].set_title('Sepal length')


axs[0,1].hist(data['SW'],bins=6)
axs[0,1].set_title('Sepal width')

axs[1,0].hist(data['PL'],color='green',bins=7)
axs[1,0].set_title('Petal length')

axs[1,1].hist(data['PW'],color='red',bins=8)
axs[1,1].set_title('Petal width')

plt.tight_layout()

plt.show()

# %% [markdown]
# From the above plot we can see that
#
# 1) The highest frequency of sepal length is between 40 to 45 which is for sepl length betweem 5.75cm to 6.5 cm
# 2) The highest frequency of sepal width is around 48 which is for sepal width around 3
# 3) The highest frequency of petal length is around 48 which is for petal length betwnne 1 to 2
# 4) The highest frequency of petal width is around 42 which is for petal width between 0.2 to 0.

# %%
plt.figure(figsize=(4,4))

sns.countplot(x='Classification',data=data,)
plt.show()

# %% [markdown]
# # Comparing  sepal length and sepal width

# %%
sns.scatterplot(x='SL', y='SW',
                hue='Classification', data=data, )
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %% [markdown]
# From the above plot we can see that
#
# 1) Iris-setosa has smaller sepal lenght but larger sepal width.
# 2) Iris-versicolor has both sepal length and sepal width intermediate between the other two.
# 3) Iris-virginica has smaller sepal width but larger sepal length.

# %% [markdown]
# # Comparing Petal length and petal width

# %%
sns.scatterplot(x='PL',y='PW',hue='Classification',data=data)
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %% [markdown]
# From the grapf we can infer that
# 1) Species setosa has smaller Petal length and Petal width.
# 2) Versicolor Species lies in the middle of the other two species in terms of petal length and width
# 3) Species Virginica has the largest of petal lengths and widths.

# %% [markdown]
# # Comparing sepal length and Petal length

# %%
sns.scatterplot(x='SL',y='PL',hue='Classification',data=data)
# Out:
# <Axes: xlabel='SL', ylabel='PL'>

# %% [markdown]
# # Comparing Sepal width and Petal width

# %%
sns.scatterplot(x='SW',y='PW',hue='Classification',data=data)
# Out:
# <Axes: xlabel='SW', ylabel='PW'>

# %% [markdown]
# From the above plot we can infer that
#
# 1) Iris-setosa has smaller Petal Length as well as smaller Petal Width.
# 2) Iris-versicolor has Petal length and Petal width intermediate between the other two species.
# 3) Iris-virginica has large Petal tength and Petal Width.

# %%
fig,axs = plt.subplots(2,2,figsize=(8,8))

axs[0,0].boxplot(data['SL'])
axs[0,0].set_title('Sepal length of different Species')


axs[0,1].boxplot(data['SW'])
axs[0,1].set_title('Sepal width of different Species')


axs[1,0].boxplot(data['PW'])
axs[1,0].set_title('Petal length of different Species')


axs[1,1].boxplot(data['PL'])
axs[1,1].set_title('Petal width of different Species')


plt.tight_layout()

plt.show()

# %%
sns.boxplot(x="Classification",y="SL", data=data)
plt.show()

# %%
sns.boxplot(x="Classification",y="SW", data=data)
plt.show()

# %%
sns.boxplot(x="Classification",y="PL", data=data)
plt.show()

# %%
sns.boxplot(x="Classification",y="PW", data=data)
plt.show()
